# %% [markdown]
# # CASE STUDY 'VANS' - Data Analysis -

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## WebScraping

# %%
df_scarpe = pd.read_csv('vans_converse_completo.csv')
df_scarpe
# Out:
#          marca              categoria  \
# 0         VANS  Sneakers alte da uomo
# 1         VANS  Sneakers alte da uomo
# 2     CONVERSE  Sneakers alte da uomo
# 3     CONVERSE  Sneakers alte da uomo
# 4     CONVERSE  Sneakers alte da uomo
# ...        ...                    ...
# 1938      VANS       Stivali da donna
# 1939      VANS       Stivali da donna
# 1940      VANS       Stivali da donna
# 1941      VANS       Stivali da donna
# 1942      VANS       Stivali da donna
#
#                                           nome_prodotto prezzo_effettivo  \
# 0     MID SKOOL 37 UNISEX - Sneakers alte - cement b...            62,99
# 1           SK8-HI UNISEX - Sneakers alte - black/white            66,49
# 2      CHUCK TAYLOR ALL STAR HI - Sneakers alte - black            66,99
# 3     CHUCK TAYLOR ALL STAR UNISEX - Sneakers alte -...            44,99
# 4     CHUCK TAYLOR ALL STAR HI - Sneakers alte - maroon            59,99
# ...                                                 ...              ...
# 1938  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...            87,99
# 1939  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...            79,99
# 1940  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...            87,99
# 1941  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...           103,99
# 1942      MTE STANDARD - Stivali da neve  - black white           143,95
#
#      prezzo_ordinario
# 0               89,99
# 1               94,99
# 2               74,99
# 3               74,99
# 4               74,99
# ...               ...
# 1938           159,99
# 1939           159,99
# 1940           159,99
# 1941           159,99
# 1942           180,00
#
# [1943 rows x 5 columns]

# %% [markdown]
# ## EDA

# %%
df_scarpe.info() #le colonne prezzo vanno cambiate in float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1943 entries, 0 to 1942
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   marca             1943 non-null   object
#  1   categoria         1943 non-null   object
#  2   nome_prodotto     1943 non-null   object
#  3   prezzo_effettivo  1943 non-null   object
#  4   prezzo_ordinario  1943 non-null   object
# dtypes: object(5)
# memory usage: 76.0+ KB

# %%
a = df_scarpe.loc[df_scarpe['prezzo_effettivo'].str.contains('tagl', regex=False)]
df_scarpe = df_scarpe.drop(a.index)
df_scarpe.count()#ho eliminato le righe che non mi servivano
# Out:
# marca               1936
# categoria           1936
# nome_prodotto       1936
# prezzo_effettivo    1936
# prezzo_ordinario    1936
# dtype: int64

# %%
df_scarpe['prezzo_effettivo'] = df_scarpe['prezzo_effettivo'].str.replace(',', '.')
df_scarpe['prezzo_ordinario'] = df_scarpe['prezzo_ordinario'].str.replace(',', '.')
df_scarpe.head()
# Out:
#       marca              categoria  \
# 0      VANS  Sneakers alte da uomo
# 1      VANS  Sneakers alte da uomo
# 2  CONVERSE  Sneakers alte da uomo
# 3  CONVERSE  Sneakers alte da uomo
# 4  CONVERSE  Sneakers alte da uomo
#
#                                        nome_prodotto prezzo_effettivo  \
# 0  MID SKOOL 37 UNISEX - Sneakers alte - cement b...            62.99
# 1        SK8-HI UNISEX - Sneakers alte - black/white            66.49
# 2   CHUCK TAYLOR ALL STAR HI - Sneakers alte - black            66.99
# 3  CHUCK TAYLOR ALL STAR UNISEX - Sneakers alte -...            44.99
# 4  CHUCK TAYLOR ALL STAR HI - Sneakers alte - maroon            59.99
#
#   prezzo_ordinario
# 0            89.99
# 1            94.99
# 2            74.99
# 3            74.99
# 4            74.99

# %%
df_scarpe['prezzo_effettivo'] = df_scarpe['prezzo_effettivo'].astype(float)
df_scarpe['prezzo_ordinario'] = df_scarpe['prezzo_ordinario'].astype(float)
df_scarpe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1936 entries, 0 to 1942
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   marca             1936 non-null   object
#  1   categoria         1936 non-null   object
#  2   nome_prodotto     1936 non-null   object
#  3   prezzo_effettivo  1936 non-null   float64
#  4   prezzo_ordinario  1936 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 90.8+ KB

# %%
df_scarpe[['modello', 'tipo', 'colore']] = df_scarpe['nome_prodotto'].str.split(' - ', expand=True)
df_scarpe
# Out:
#          marca              categoria  \
# 0         VANS  Sneakers alte da uomo
# 1         VANS  Sneakers alte da uomo
# 2     CONVERSE  Sneakers alte da uomo
# 3     CONVERSE  Sneakers alte da uomo
# 4     CONVERSE  Sneakers alte da uomo
# ...        ...                    ...
# 1938      VANS       Stivali da donna
# 1939      VANS       Stivali da donna
# 1940      VANS       Stivali da donna
# 1941      VANS       Stivali da donna
# 1942      VANS       Stivali da donna
#
#                                           nome_prodotto  prezzo_effettivo  \
# 0     MID SKOOL 37 UNISEX - Sneakers alte - cement b...             62.99
# 1           SK8-HI UNISEX - Sneakers alte - black/white             66.49
# 2      CHUCK TAYLOR ALL STAR HI - Sneakers alte - black             66.99
# 3     CHUCK TAYLOR ALL STAR UNISEX - Sneakers alte -...             44.99
# 4     CHUCK TAYLOR ALL STAR HI - Sneakers alte - maroon             59.99
# ...                                                 ...               ...
# 1938  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...             87.99
# 1939  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...             79.99
# 1940  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...             87.99
# 1941  MTE SK8-HI WATERPROOF UNISEX - Stivali da neve...            103.99
# 1942      MTE STANDARD - Stivali da neve  - black white            143.95
#
#       prezzo_ordinario                       modello              tipo  \
# 0                89.99           MID SKOOL 37 UNISEX     Sneakers alte
# 1                94.99                 SK8-HI UNISEX     Sneakers alte
# 2                74.99      CHUCK TAYLOR ALL STAR HI     Sneakers alte
# 3                74.99  CHUCK TAYLOR ALL STAR UNISEX     Sneakers alte
# 4                74.99      CHUCK TAYLOR ALL STAR HI     Sneakers alte
# ...                ...                           ...               ...
# 1938            159.99  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1939            159.99  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1940            159.99  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1941            159.99  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1942            180.00                  MTE STANDARD  Stivali da neve
#
#                   colore
# 0     cement blue/impala
# 1            black/white
# 2                  black
# 3          stingray grey
# 4                 maroon
# ...                  ...
# 1938       glazed ginger
# 1939               black
# 1940                teak
# 1941        scarab/black
# 1942         black white
#
# [1936 rows x 8 columns]

# %%
df_scarpe['gender'] = df_scarpe['categoria'].str.split('da').str[1]
df_scarpe.head()
# Out:
#       marca              categoria  \
# 0      VANS  Sneakers alte da uomo
# 1      VANS  Sneakers alte da uomo
# 2  CONVERSE  Sneakers alte da uomo
# 3  CONVERSE  Sneakers alte da uomo
# 4  CONVERSE  Sneakers alte da uomo
#
#                                        nome_prodotto  prezzo_effettivo  \
# 0  MID SKOOL 37 UNISEX - Sneakers alte - cement b...             62.99
# 1        SK8-HI UNISEX - Sneakers alte - black/white             66.49
# 2   CHUCK TAYLOR ALL STAR HI - Sneakers alte - black             66.99
# 3  CHUCK TAYLOR ALL STAR UNISEX - Sneakers alte -...             44.99
# 4  CHUCK TAYLOR ALL STAR HI - Sneakers alte - maroon             59.99
#
#    prezzo_ordinario                       modello           tipo  \
# 0             89.99           MID SKOOL 37 UNISEX  Sneakers alte
# 1             94.99                 SK8-HI UNISEX  Sneakers alte
# 2             74.99      CHUCK TAYLOR ALL STAR HI  Sneakers alte
# 3             74.99  CHUCK TAYLOR ALL STAR UNISEX  Sneakers alte
# 4             74.99      CHUCK TAYLOR ALL STAR HI  Sneakers alte
#
#                colore gender
# 0  cement blue/impala   uomo
# 1         black/white   uomo
# 2               black   uomo
# 3       stingray grey   uomo
# 4              maroon   uomo

# %%
#df_scarpe = df_scarpe.drop(columns=['categoria'])
df_scarpe = df_scarpe.drop(columns=['nome_prodotto'])
df_scarpe.head()
# Out:
#       marca              categoria  prezzo_effettivo  prezzo_ordinario  \
# 0      VANS  Sneakers alte da uomo             62.99             89.99
# 1      VANS  Sneakers alte da uomo             66.49             94.99
# 2  CONVERSE  Sneakers alte da uomo             66.99             74.99
# 3  CONVERSE  Sneakers alte da uomo             44.99             74.99
# 4  CONVERSE  Sneakers alte da uomo             59.99             74.99
#
#                         modello           tipo              colore gender
# 0           MID SKOOL 37 UNISEX  Sneakers alte  cement blue/impala   uomo
# 1                 SK8-HI UNISEX  Sneakers alte         black/white   uomo
# 2      CHUCK TAYLOR ALL STAR HI  Sneakers alte               black   uomo
# 3  CHUCK TAYLOR ALL STAR UNISEX  Sneakers alte       stingray grey   uomo
# 4      CHUCK TAYLOR ALL STAR HI  Sneakers alte              maroon   uomo

# %%
for index, row in df_scarpe.iterrows():
    if 'unisex' in row['modello'].lower():
        df_scarpe.at[index, 'gender'] = 'unisex'

df_scarpe
# Out:
#          marca              categoria  prezzo_effettivo  prezzo_ordinario  \
# 0         VANS  Sneakers alte da uomo             62.99             89.99
# 1         VANS  Sneakers alte da uomo             66.49             94.99
# 2     CONVERSE  Sneakers alte da uomo             66.99             74.99
# 3     CONVERSE  Sneakers alte da uomo             44.99             74.99
# 4     CONVERSE  Sneakers alte da uomo             59.99             74.99
# ...        ...                    ...               ...               ...
# 1938      VANS       Stivali da donna             87.99            159.99
# 1939      VANS       Stivali da donna             79.99            159.99
# 1940      VANS       Stivali da donna             87.99            159.99
# 1941      VANS       Stivali da donna            103.99            159.99
# 1942      VANS       Stivali da donna            143.95            180.00
#
#                            modello              tipo              colore  \
# 0              MID SKOOL 37 UNISEX     Sneakers alte  cement blue/impala
# 1                    SK8-HI UNISEX     Sneakers alte         black/white
# 2         CHUCK TAYLOR ALL STAR HI     Sneakers alte               black
# 3     CHUCK TAYLOR ALL STAR UNISEX     Sneakers alte       stingray grey
# 4         CHUCK TAYLOR ALL STAR HI     Sneakers alte              maroon
# ...                            ...               ...                 ...
# 1938  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve        glazed ginger
# 1939  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve                black
# 1940  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve                 teak
# 1941  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve         scarab/black
# 1942                  MTE STANDARD  Stivali da neve          black white
#
#       gender
# 0     unisex
# 1     unisex
# 2       uomo
# 3     unisex
# 4       uomo
# ...      ...
# 1938  unisex
# 1939  unisex
# 1940  unisex
# 1941  unisex
# 1942   donna
#
# [1936 rows x 8 columns]

# %%
df_scarpe = df_scarpe.drop(columns=['categoria'])
df_scarpe
# Out:
#          marca  prezzo_effettivo  prezzo_ordinario  \
# 0         VANS             62.99             89.99
# 1         VANS             66.49             94.99
# 2     CONVERSE             66.99             74.99
# 3     CONVERSE             44.99             74.99
# 4     CONVERSE             59.99             74.99
# ...        ...               ...               ...
# 1938      VANS             87.99            159.99
# 1939      VANS             79.99            159.99
# 1940      VANS             87.99            159.99
# 1941      VANS            103.99            159.99
# 1942      VANS            143.95            180.00
#
#                            modello              tipo              colore  \
# 0              MID SKOOL 37 UNISEX     Sneakers alte  cement blue/impala
# 1                    SK8-HI UNISEX     Sneakers alte         black/white
# 2         CHUCK TAYLOR ALL STAR HI     Sneakers alte               black
# 3     CHUCK TAYLOR ALL STAR UNISEX     Sneakers alte       stingray grey
# 4         CHUCK TAYLOR ALL STAR HI     Sneakers alte              maroon
# ...                            ...               ...                 ...
# 1938  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve        glazed ginger
# 1939  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve                black
# 1940  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve                 teak
# 1941  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve         scarab/black
# 1942                  MTE STANDARD  Stivali da neve          black white
#
#       gender
# 0     unisex
# 1     unisex
# 2       uomo
# 3     unisex
# 4       uomo
# ...      ...
# 1938  unisex
# 1939  unisex
# 1940  unisex
# 1941  unisex
# 1942   donna
#
# [1936 rows x 7 columns]

# %%
df_scarpe = df_scarpe[['marca','modello','tipo','colore','gender','prezzo_effettivo','prezzo_ordinario']]
df_scarpe
# Out:
#          marca                       modello              tipo  \
# 0         VANS           MID SKOOL 37 UNISEX     Sneakers alte
# 1         VANS                 SK8-HI UNISEX     Sneakers alte
# 2     CONVERSE      CHUCK TAYLOR ALL STAR HI     Sneakers alte
# 3     CONVERSE  CHUCK TAYLOR ALL STAR UNISEX     Sneakers alte
# 4     CONVERSE      CHUCK TAYLOR ALL STAR HI     Sneakers alte
# ...        ...                           ...               ...
# 1938      VANS  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1939      VANS  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1940      VANS  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1941      VANS  MTE SK8-HI WATERPROOF UNISEX  Stivali da neve
# 1942      VANS                  MTE STANDARD  Stivali da neve
#
#                   colore  gender  prezzo_effettivo  prezzo_ordinario
# 0     cement blue/impala  unisex             62.99             89.99
# 1            black/white  unisex             66.49             94.99
# 2                  black    uomo             66.99             74.99
# 3          stingray grey  unisex             44.99             74.99
# 4                 maroon    uomo             59.99             74.99
# ...                  ...     ...               ...               ...
# 1938       glazed ginger  unisex             87.99            159.99
# 1939               black  unisex             79.99            159.99
# 1940                teak  unisex             87.99            159.99
# 1941        scarab/black  unisex            103.99            159.99
# 1942         black white   donna            143.95            180.00
#
# [1936 rows x 7 columns]

# %%
df_scarpe.describe()
# Out:
#        prezzo_effettivo  prezzo_ordinario
# count       1936.000000       1936.000000
# mean          73.597087         97.257397
# std           23.977286         22.527756
# min           36.990000         37.000000
# 25%           54.990000         84.990000
# 50%           67.990000         90.000000
# 75%           85.990000        104.500000
# max          189.000000        249.990000

# %%
duplicati = df_scarpe.duplicated()
duplicati.sum()
df_duplicati = df_scarpe[df_scarpe.duplicated()]
df_duplicati.shape[0]
# Out:
# 597

# %%
# elimino i duplicati perchè potrebbe falsare i dati
df_scarpe_new = df_scarpe.drop_duplicates()
df_scarpe_new.sample()
# Out:
#        marca          modello           tipo                colore  gender  \
# 69  CONVERSE  CHUCK 70 UNISEX  Sneakers alte  park red/egret/black  unisex
#
#     prezzo_effettivo  prezzo_ordinario
# 69             94.99             94.99

# %%
df_scarpe_new = df_scarpe_new.rename(columns={"tipo": "categoria"})

# %%
df_scarpe_new
# Out:
#          marca                                            modello  \
# 0         VANS                                MID SKOOL 37 UNISEX
# 1         VANS                                      SK8-HI UNISEX
# 2     CONVERSE                           CHUCK TAYLOR ALL STAR HI
# 3     CONVERSE                       CHUCK TAYLOR ALL STAR UNISEX
# 4     CONVERSE                           CHUCK TAYLOR ALL STAR HI
# ...        ...                                                ...
# 1928  CONVERSE                   CHUCK TAYLOR ALL STAR LUGGED 2.0
# 1931  CONVERSE                         CHUCK TAYLOR ALL STAR XXHI
# 1936  CONVERSE  CHUCK TAYLOR ALL STAR LUGGED 2.0 WATERPROOF PL...
# 1941      VANS                       MTE SK8-HI WATERPROOF UNISEX
# 1942      VANS                                       MTE STANDARD
#
#                    categoria                       colore  gender  \
# 0              Sneakers alte           cement blue/impala  unisex
# 1              Sneakers alte                  black/white  unisex
# 2              Sneakers alte                        black    uomo
# 3              Sneakers alte                stingray grey  unisex
# 4              Sneakers alte                       maroon    uomo
# ...                      ...                          ...     ...
# 1928  Stivaletti con plateau              black/sharkskin   donna
# 1931     Stivali con i lacci                        black   donna
# 1936        Stivali da neve   fresh brew/fresh brew/black   donna
# 1941        Stivali da neve                  scarab/black  unisex
# 1942        Stivali da neve                   black white   donna
#
#       prezzo_effettivo  prezzo_ordinario
# 0                62.99             89.99
# 1                66.49             94.99
# 2                66.99             74.99
# 3                44.99             74.99
# 4                59.99             74.99
# ...                ...               ...
# 1928             76.99            139.99
# 1931             99.99             99.99
# 1936             69.99            139.99
# 1941            103.99            159.99
# 1942            143.95            180.00
#
# [1339 rows x 7 columns]

# %%
sneacker_alte = df_scarpe_new.groupby("categoria")["modello"].count()
sneacker_alte
# Out:
# categoria
# Scarpe senza lacci             23
# Scarpe skate                  139
# Sneakers alte                 474
# Sneakers basse                648
# Stivaletti con plateau          5
# Stivaletti con tacco            2
# Stivaletti stringati            4
# Stivali con i lacci             1
# Stivali da neve                 9
# Stringate sportive              4
# Tronchetti                      2
# beige                           1
# black                           4
# black / white                   1
# black off white                 1
# black/true white                2
# brown                           2
# charcoal                        2
# fairway                         2
# glazed ginger                   2
# lime                            2
# pink bubblegum black white      1
# pink grey                       1
# port royale/true white          2
# purple                          1
# schwarz                         1
# turtledove                      2
# white                           1
# Name: modello, dtype: int64

# %%
df_scarpe_new["categoria"].unique()
# Out:
# array(['Sneakers alte', 'beige', 'Scarpe skate',
#        'pink bubblegum black white', 'black', 'Sneakers basse',
#        'port royale/true white', 'Scarpe senza lacci', 'black/true white',
#        'glazed ginger', 'turtledove', 'charcoal', 'brown', 'lime',
#        'fairway', 'black / white', 'Stivali da neve ',
#        'Stivaletti con plateau', 'Stivaletti stringati',
#        'Stringate sportive', 'pink grey', 'purple', 'black off white',
#        'schwarz', 'white', 'Stivaletti con tacco', 'Tronchetti',
#        'Stivali con i lacci'], dtype=object)

# %%
# Ci siamo accorti che nello split alcuni colori erano subentrati nella categoria, quindi, con queste righe di codice li abbiamo spostate
df_scarpe_new.loc[df_scarpe_new['colore'].isnull(), 'colore'] = df_scarpe_new['categoria']
df_scarpe_new.loc[df_scarpe_new['colore'] == df_scarpe_new['categoria'], 'categoria'] = None


df_scarpe_new["modello"].unique()
# Out:
# array(['MID SKOOL 37 UNISEX', 'SK8-HI UNISEX', 'CHUCK TAYLOR ALL STAR HI',
#        'CHUCK TAYLOR ALL STAR UNISEX',
#        'CHUCK TAYLOR ALL STAR CLASSIC WIDE',
#        'CHUCK TAYLOR ALL STAR MALDEN STREET UNISEX', 'CHUCK 70',
#        'RUN STAR HIKE', 'SK8 HI UNISEX', 'CHUCK TAYLOR ALL STAR HI ',
#        'CHUCK TAYLOR ALL STAR CITY TREK', 'CHUCK TAYLOR UNISEX',
#        'SK8 HI TAPERED', 'CHUCK TAYLOR ALL STAR MALDEN STREET',
#        'STAR PLAYER 76 UNISEX', 'CHUCK TAYLOR ALL STAR CITY TREK UNISEX',
#        'CHUCK UNISEX', 'CHUCK 70 UNISEX',
#        'CHUCK TAYLOR ALL STAR WIDE UNISEX',
#        'CHUCK TAYLOR ALL STAR WIDE FIT ', 'PRO BLAZE CLASSIC UNISEX',
#        'CHUCK 70 FUTURE COMFORT UNISEX',
#        'CHUCK TAYLOR ALL STAR CLASSIC UNISEX',
#        'CHUCK TAYLOR ALL STAR LTD UNISEX', 'Sneakers alte',
#        'CHUCK GEO FORMA', 'MTE SK8-HI WATERPROOF UNISEX',
#        'CHUCK 70 PLUS XHI', 'OLD SKOOL WIDE', 'KNU MID UNISEX',
#        'MTE CROSSPATH MID ', 'WEAPON VINTAGE UNISEX',
#        'CHUCK TAYLOR ALL STAR', 'HALF CAB ', 'SK8-HI TAPERED UNISEX',
#        'CHUCK TAYLOR ALL STAR EQUIP WP UNISEX', 'CHUCK 70 HI UNISEX',
#        'CHUCK PRISM ', 'ULTRARANGE EXO HI MTE-1 UNISEX',
#        'CHUCK TAYLOR ZEITLOSE ', 'CHUCK 70 FALL TONE UNISEX', 'CHUCK ',
#        'RECONSTRUCT', 'CHUCK TAYLOR ALL STAR LUGGED 2.0 UNISEX',
#        'CHUCK 70 SPRAY PAINT UNISEX', 'SK8-HI MTE UNISEX',
#        'CHUCK TAYLOR ALL STAR NACHHALTIGE ', 'PRO BLAZE UNISEX',
#        'RUN STAR LEGACY UNISEX', 'UA SK8-MID REISSUE',
#        'CHUCK 70 SPRING COLOR UNISEX', 'FILMORE HI ', 'SK8-HI VR3 UNISEX',
#        'ULTRARANGE EXO HI MTE-2 UNISEX',
#        'CHUCK TAYLOR ALL STAR BERKSHIRE BOOT WATER-REPELLENT UNISEX',
#        'CHUCK TAYLOR ALL STAR BERKSHIRE UNISEX',
#        'CHUCK TAYLOR ALL STAR EQUIP WATERPROOF UNISEX', 'SK8-HI REISSUE',
#        'CONVERSE X BEYOND RETRO CHUCK 70 UNISEX ',
#        'CHUCK TAYLOR ALL STAR CITY TREK WATERPROOF BOOT UNISEX',
#        'CHUCK 70 AT CX UNISEX', 'MTE SK8-HI GORE TEX UNISEX',
#        'CHUCK 70 HICKORY STRIPE UNISEX', 'SK8-HI MTE-2 UNISEX',
#        'SK HI MTE UNISEX', 'CHUCK 70 GTX UNISEX',
#        'MTE HALF CAB GORE TEX UNISEX', 'WEAPON COLORBLOCKED UNISEX',
#        'CHUCK TAYLOR ALL STAR TERRAIN UTILITY',
#        'CHUCK TAYLOR ALL STAR TECTUFF WATERPROOF CAMO',
#        'DESTRUCT MID MTE-1 UNISEX',
#        'CHUCK TAYLOR ALL STAR LUGGED WINTER UNISEX',
#        'CHUCK 70 SUMMER TONE UNISEX', 'RUN STAR HIKE SEASONAL UNISEX',
#        'CHUCK 70 MULTI-STITCH UNISEX',
#        'CHUCK TAYLOR ALL STAR BORO STITCH UNISEX', 'UA  STACKFORM',
#        'SK8-HI', 'CHUCK TAYLOR ALL STAR CITY TREK WATERPROOF UNISEX',
#        'CHUCK TAYLOR',
#        'CHUCK TAYLOR ALL STAR BERKSHIRE WATER REPELLENT UNISEX',
#        'CHUCK 70 ARCHIVAL STRIPES UNISEX', 'ALL STAR BERKSHIRE UNISEX',
#        'CHUCK TAYLOR ALL STAR CITY UNISEX ', 'OLD SKOOL UNISEX',
#        'SK8 LOW UNISEX', 'STAR PLAYER UNISEX', 'SK8-LOW UNISEX',
#        'UA OLD SKOOL', 'Sneakers basse', 'AUTHENTIC UNISEX',
#        'CHUCK TAYLOR ALL STAR WIDE FIT UNISEX',
#        'CHUCK TAYLOR ALL STAR OX UNISEX', 'KNU SKOOL UNISEX',
#        'HYLANE UNISEX', 'OLD SKOOL TAPERED UNISEX', 'CRUZE UNISEX',
#        'CLASSIC SLIP-ON UNISEX', 'SPORT LOW', 'PRO BLAZE V2 UNISEX',
#        'ROWLEY CLASSIC UNISEX', 'UA CLASSIC SLIP-ON UNISEX',
#        'CHUCK TAYLOR ALL STAR OX', 'ULTRARANGE NEO UNISEX', 'UA ERA',
#        'CLASSIC SLIP-ON', 'SPEED UNISEX', 'PREMIUM OLD SKOOL UNISEX',
#        'ULTRARANGE NEO VR3 UNISEX', 'UPLAND UNISEX',
#        'MTE CROSSPATH UNISEX', 'CROSSPATH UNISEX', 'UA CLASSIC SLIP-ON',
#        'PRO BLAZE V2', 'CLASSIC SLIP ON UNISEX', 'SPORT CASUAL UNISEX',
#        'SPORT LOW UNISEX', 'KNU', 'CLASSIC SLIP ON UNISEX ', 'OLD SKOOL',
#        'HYLANE', 'SLIP-ER 2 UNISEX', 'SNEAKER', 'STAR PLAYER PUFF UNISEX',
#        'AUTHENTIC.', 'PREMIUM LX AUTHENTIC REISSUE 44 UNISEX',
#        'LOWLAND CC UNISEX', 'SUPER LOWPRO',
#        'OLD SKOOL 36 ANAHEIM FACTORY', 'CRUZE TOO CC UNISEX', 'SKOOL',
#        'UA COMFYCUSH ERA', 'UPLAND MULE UNISEX', 'AUTHENTIC', 'WARD',
#        'CHUKKA PUSH UNISEX', 'CHUKKA ', 'CALDRONE', 'SPEED LS UNISEX',
#        'VANS SCHNÜRSCHUHE', 'ROWLEY XLT UNISEX', 'CONVERSE',
#        'CONVERSE x BEYOND RETRO CHUCK 70 OX UNISEX',
#        'UA OLD SKOOL OVERT CC', 'CHUCK TAYLOR  ', 'ONE STAR ACADEMY PRO',
#        'UA SENTRY OLD SKOOL WC', 'KNU STACK', 'ONE STAR PRO OX UNISEX',
#        'CHUCK 70 OX UNISEX', 'FILMORE ', 'OBSIDIAN',
#        'UA OLD SKOOL GTX VR3 RAEB DBEIG', 'UA AUTHENTIC 44 DX OUR MONG ',
#        'UA BOLD NI', 'OLD SKOOL  DX WS ROKI TRNSL', 'UNISEX',
#        'CHUCK TAYLOR ALL STAR BORO STITCHING UNISEX', 'LOWLAND UNISEX',
#        'ULTRARANGE EXO', 'PRO BLAZE CLASSIC RETRO 90S UNISEX',
#        'PRO UNISEX', 'ULTRARANGE EXO UNISEX', 'CRUZE TOO UNISEX',
#        'ATWOOD', 'STAR PLAYER 76 TECTUFF OVERLAYS UNISEX',
#        'OLD SKOOL MTE 1 UNISEX', "PRO BLAZE CLASSIC RETRO '90S UNISEX",
#        'PRO LEATHER', 'OLD SKOOL LUX UNISEX', 'ERA',
#        'MTE OLD SKOOL WATERPROOF UNISEX', 'CONS PRO UNISEX',
#        'STAR PLAYER 76 FALL UNISEX', 'MTE ULTRARANGE EXO UNISEX',
#        'SPORT UNISEX', 'PL VULC PRO UNISEX', 'CHUCK ALL STAR UNISEX',
#        'AUTHENTIC LUX UNISEX', 'OLD SKOOL LOWPRO UNISEX',
#        'CHUCK 70 WIDE UNISEX', 'UA SID', 'EVDNT ULTIMATEWAFFLE UNISEX',
#        'UA AUTHENTIC', 'UA AUTHENTIC ANPA DBEIG', 'AMZN TRAILHEAD UNISEX',
#        'UA VANS SPORT', 'ERA UNISEX', 'VULC PRO UNISEX',
#        'MTE STANDARD MID CHELSEA WATERPROOF UNISEX', 'MTE STANDARD',
#        'MTE SNOW-KICKER GORE-TEX UNISEX',
#        'CHUCK TAYLOR ALL STAR BALLET LACE', 'AUTHENTIC LOW PRO ',
#        'CLASSIC UNISEX', 'CLASSIC STACKFORM', 'CLASSIC ',
#        'Scarpe senza lacci', 'MID SLIP MTE 1 UNISEX',
#        'UA SK8-HI PLATFORM 2.0', 'CHUCK TAYLOR ALL STAR LIFT',
#        'CHUCK TAYLOR ALL STAR MOVE PLATFORM RETRO SPORT',
#        'CHUCK TAYLOR ALL STAR MOVE',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM', 'CHUCK 70 DE LUXE SQUARED',
#        'CHUCK TAYLOR ALL STAR MOVE PLATFORM', 'CHUCK TAYLOR LIFT',
#        'WM FILMORE HI', 'CHUCK TAYLOR ALL STAR LIFT  ',
#        'CHUCK TAYLOR ALL STAR CRUISE', 'CHUCK 70 DE LUXE HEEL',
#        'CHUCK TAYLOR ALL STAR WEDGE',
#        'CHUCK TAYLOR ALL STAR LUGGED HEEL LEATHER PLATFORM',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM WIDE WIDTH',
#        'CHUCK 70 WEDGE PLATFORM', 'CHUCK 70 DE LUXE WEDGE', 'CHUCK 70 HI',
#        'CHUCK 70 INTERNAL WEDGE PREMIUM',
#        'CHUCK TAYLOR ALL STAR WEDGE PLATFORM', 'CHUCK 70 PLUS HI SUMMIT',
#        'CHUCK ORIGINALS', 'CHUCK TAYLOR ALL STAR MOVE ',
#        'CHUCK TAYLOR ALL STAR LUGGED HEEL PLATFORM',
#        'CHUCK TAYLOR ALL STAR RETRO', 'CHUCK 70 PLUS HI',
#        'CHUCK 70 WEDGE PLATFORM LUXE PONY HAIR', 'CHUCK 70 PLUS',
#        'CHUCK 70 PLUS HI SUNRISE ', 'UA SK8-HI TAPERED',
#        'CHUCK 70 PLUS XHI PONY HAIR', 'CHUCK 70 WORKWEAR ',
#        'RUN STAR UTILITY', 'CHUCK TAYLOR ALL STAR WEATHERIZED',
#        'RUN STAR LEGACY PLATFORM SEASONAL COLOR',
#        'RUN STAR HIKE PLATFORM', 'CHUCK TAYLOR ALL STAR ',
#        'CHUCK TAYLOR ALL STAR CRUISE PLATFORM',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM ASHION',
#        'RUN STAR LEGACY CX SEASONAL', 'CHUCK 70 SHIMMER',
#        'SK8-HI TAPERED STACKFORM',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM GLITTER', 'CHUCK 70 ',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM WORKWEAR',
#        'CHUCK TAYLOR ALL STAR CRUISE XL',
#        'CHUCK TAYLOR ALL STAR TAILORED LINES', 'CHUCK 70 COUNTER CLIMATE',
#        'RUN STAR HIKE PLATFORM WEATHERIZED',
#        'CHUCK TAYLOR ALL STAR FASHION',
#        'CHUCK TAYLOR ALL STAR LIFT PLATFORM SEASONAL COLOR',
#        'CHUCK TAYLOR ALL STAR CRAFTED FLORALS',
#        'CHUCK TAYLOR ALL STAR MALDEN STREET WIDE FIT UNISEX',
#        'CHUCK TAYLOR ALL STAR LUGGED 2.0 SUMMER UTILITY',
#        'UA SK8-HI TAPERED UNISEX', 'CHUCK TAYLOR ALL STAR MONO',
#        'UA OLD SKOOL STACKFORM', 'CHUCK TAYLOR ALL STAR DAINTY BASIC',
#        'CHUCK TAYLOR MOVE PLATFORM', 'UA OLD SKOOL PLATFORM',
#        'RUN STAR TRAINER', 'CLASSIC SLIP-ON PLATFORM',
#        'CHUCK TAYLOR ALL STAR DAINTY', 'RUN STAR TRAINER EXCLUSIVE',
#        'CHUCK TAYLOR ALL STAR 70 UNISEX',
#        'CHUCK TAYLOR ALL STAR INTERNAL WEDGE', 'STAR PLAYER 76',
#        'KNU SKOOL', 'SNEAKER  ', 'CHUCK TAYLOR ', 'PRO LIFT',
#        'AUTHENTIC VIBRAM DX', 'ULTRARANGE NEO ',
#        'CHUCK TAYLOR ALL STAR LIFT WIDE', 'AUTHENTIC PLATFORM 2.0',
#        'SK8-LOW', 'COMFYCUSH AUTHENTIC',
#        'CHUCK TAYLOR ALL STAR DAINTY BASIC ', 'LOWLAND ',
#        'UA AUTHENTIC STACKFORM', 'OLD SKOOL PLATFORM',
#        'AUTHENTIC STACKFORM', 'OLD SKOOL STACKFORM',
#        'CHUCK TAYLOR ALL STAR CRUISE ', 'CHUCK 70 DE LUXE',
#        'CHUCK 70 DE LUXE ', 'CHUCK 70 DE LUXE HEEL PLATFORM',
#        'CHUCK 70 DE LUXE WEDGE PLATFORM', 'CHUCK 70 DE LUXE PLATFORM',
#        'CHUCK TAYLOR ALL STAR LUGGED 2.0', 'CHUCK TAYLOR ALL STAR XXHI',
#        'CHUCK TAYLOR ALL STAR LUGGED 2.0 WATERPROOF PLATFORM'],
#       dtype=object)

# %%
df_sneakers = df_scarpe_new.loc[df_scarpe_new["categoria"].isin(["Sneakers alte","Sneakers basse"])]

# %%
df_altre_categorie = df_scarpe_new.loc[~df_scarpe_new["categoria"].isin(["Sneakers alte","Sneakers basse","Scarpe skate"])]

# %%
df_skate = df_scarpe_new.loc[df_scarpe_new["categoria"].isin(["Scarpe skate"])]

# %% [markdown]
# ## Grafici

# %%
palette = ["#003366"]
plt.figure(figsize=(20,10))
sns.countplot(data = df_scarpe_new, x="categoria", palette = palette)
plt.title("Categorie in vendita su zalando",fontsize = 20)
plt.xlabel("Categorie", fontsize = 15)
plt.ylabel("Conteggio prodotti", fontsize = 15)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Categorie.png', dpi=300, bbox_inches='tight')
# Out:
# /var/folders/f5/1w93tbks3czcwl83tpj_2j4h0000gn/T/ipykernel_56218/888136488.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df_scarpe_new, x="categoria", palette = palette)
# /var/folders/f5/1w93tbks3czcwl83tpj_2j4h0000gn/T/ipykernel_56218/888136488.py:3: UserWarning:
# The palette list has fewer values (1) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data = df_scarpe_new, x="categoria", palette = palette)
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"] 
plt.figure(figsize=(20,10))
sns.countplot(data = df_scarpe_new, x="categoria",hue= "marca",palette = palette)
plt.title("Categorie in vendita su zalando",fontsize = 20)
plt.xlabel("Categorie", fontsize = 15)
plt.ylabel("Conteggio prodotti", fontsize = 15)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Categorie_marca.png', dpi=300, bbox_inches='tight')
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"]
plt.figure(figsize=(5,5))
sns.countplot(data = df_sneakers, x="categoria", hue= "marca", palette = palette)
plt.title("Sneakers in vendita su zalando",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Conteggio prodotti", fontsize = 8)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Sneakers.png', dpi=300, bbox_inches='tight')
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
print(df_sneakers.groupby(["marca", "categoria"] )["categoria"].count())
# Out:
# marca     categoria
# CONVERSE  Sneakers alte     355
#           Sneakers basse    222
# VANS      Sneakers alte     119
#           Sneakers basse    426
# Name: categoria, dtype: int64

# %%
palette = ["#E60012","#003366"]  
plt.figure(figsize=(15,15))
sns.countplot(data = df_altre_categorie, x="categoria",hue= "marca", palette = palette)
plt.title("Other categories in vendita su zalando",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Conteggio prodotti", fontsize = 8)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Altre_categorie.png', dpi=300, bbox_inches='tight')
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"]   
plt.figure(figsize=(4,8))
sns.countplot(data = df_skate, x="categoria", hue = 'marca', palette = palette)
plt.title("Skate",fontsize = 20)
plt.xlabel("Categorie", fontsize = 15)
plt.ylabel("Conteggio prodotti", fontsize = 15)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Skate.png', dpi=300, bbox_inches='tight')
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#E60012","#003366"]
plt.figure(figsize=(7,7))
sns.barplot(data = df_altre_categorie, x="categoria", y="prezzo_effettivo", hue= "marca", palette = palette, errorbar =None )
plt.title("Prezzi prodotti sneaker",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Prezzo medio €", fontsize = 8)
plt.xticks(rotation = 45)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/prezzi_per_categorie.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"]
plt.figure(figsize=(5,5))
sns.barplot(data = df_sneakers, x="categoria", y="prezzo_effettivo", hue= "marca", palette = palette, errorbar = None)
plt.title("Prezzi prodotti sneaker",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Prezzo medio €", fontsize = 8)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/prezzi_sneaker.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"]
plt.figure(figsize=(5,5))
sns.boxplot(data = df_sneakers, x="categoria", y="prezzo_effettivo", hue= "marca", palette = palette)
plt.title("Prezzi prodotti sneaker",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Prezzo medio €", fontsize = 8)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/boxplot_prezzi_sneaker.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
prezzo_minimo_effettivo = df_scarpe_new.groupby("marca")["prezzo_effettivo"].min().reset_index()
print(f"I prezzi minimi delle due marche sono: {prezzo_minimo_effettivo}")

prezzo_max_effettivo = df_scarpe_new.groupby("marca")["prezzo_effettivo"].max().reset_index()
print(f"I prezzi massimi delle due marche sono: {prezzo_max_effettivo}")

media_prezzo_effettivo = df_scarpe_new.groupby(["marca", "categoria"])["prezzo_effettivo"].mean().reset_index()

media_prezzo_ordinario = df_scarpe_new.groupby(["marca", "categoria"])["prezzo_ordinario"].mean().reset_index()


media_prezzo_effettivo = pd.DataFrame(media_prezzo_effettivo)
media_prezzo_ordinario = pd.DataFrame(media_prezzo_ordinario)
# Out:
# I prezzi minimi delle due marche sono:       marca  prezzo_effettivo
# 0  CONVERSE             37.00
# 1      VANS             36.99
# I prezzi massimi delle due marche sono:       marca  prezzo_effettivo
# 0  CONVERSE             168.0
# 1      VANS             189.0

# %%
palette = ["#E60012", "#003366"]
plt.figure(figsize=(10,10))
sns.barplot(data = media_prezzo_effettivo, x="categoria", y="prezzo_effettivo", hue= "marca", palette = palette, errorbar = None)
plt.title("Prezzi medi effettivi per tutte le categorie",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Prezzo medio €", fontsize = 8)
plt.xticks(rotation = 45)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/prezzi_medi_effettivi.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
# Prezzi scontati
df_prezzi_scontati = df_scarpe_new.loc[df_scarpe_new["prezzo_effettivo"] != df_scarpe_new["prezzo_ordinario"]]
display(df_prezzi_scontati)

print(f"I prodotti delle due marche sono in totale: {df_scarpe_new.shape[0]}")
# Out:
#          marca                                            modello  \
# 0         VANS                                MID SKOOL 37 UNISEX
# 1         VANS                                      SK8-HI UNISEX
# 2     CONVERSE                           CHUCK TAYLOR ALL STAR HI
# 3     CONVERSE                       CHUCK TAYLOR ALL STAR UNISEX
# 4     CONVERSE                           CHUCK TAYLOR ALL STAR HI
# ...        ...                                                ...
# 1927  CONVERSE                    CHUCK 70 DE LUXE WEDGE PLATFORM
# 1928  CONVERSE                   CHUCK TAYLOR ALL STAR LUGGED 2.0
# 1936  CONVERSE  CHUCK TAYLOR ALL STAR LUGGED 2.0 WATERPROOF PL...
# 1941      VANS                       MTE SK8-HI WATERPROOF UNISEX
# 1942      VANS                                       MTE STANDARD
#
#                    categoria                       colore  gender  \
# 0              Sneakers alte           cement blue/impala  unisex
# 1              Sneakers alte                  black/white  unisex
# 2              Sneakers alte                        black    uomo
# 3              Sneakers alte                stingray grey  unisex
# 4              Sneakers alte                       maroon    uomo
# ...                      ...                          ...     ...
# 1927              Tronchetti     lavender ash/egret/black   donna
# 1928  Stivaletti con plateau              black/sharkskin   donna
# 1936        Stivali da neve   fresh brew/fresh brew/black   donna
# 1941        Stivali da neve                  scarab/black  unisex
# 1942        Stivali da neve                   black white   donna
#
#       prezzo_effettivo  prezzo_ordinario
# 0                62.99             89.99
# 1                66.49             94.99
# 2                66.99             74.99
# 3                44.99             74.99
# 4                59.99             74.99
# ...                ...               ...
# 1927             64.99            129.99
# 1928             76.99            139.99
# 1936             69.99            139.99
# 1941            103.99            159.99
# 1942            143.95            180.00
#
# [951 rows x 7 columns]
# I prodotti delle due marche sono in totale: 1339

# %%
# Quanti prodotti sono in sconto per le due marche?

palette = ["#003366","#E60012"]
plt.figure(figsize=(10,10))
sns.countplot(data = df_prezzi_scontati, x="categoria", hue= "marca", palette = palette)
plt.title("Prodotti scontati",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Conteggio prodotti", fontsize = 8)
plt.xticks(rotation = 45)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/prodotti_scontati.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
palette = ["#003366","#E60012"]
plt.figure(figsize=(10,10))
sns.barplot(data = df_scarpe_new, x="categoria", y="prezzo_effettivo", hue= "marca", palette = palette, errorbar = None)
plt.title("Prezzi per tutte le categorie",fontsize = 10)
plt.xlabel("Categorie", fontsize = 8)
plt.ylabel("Prezzo medio €", fontsize = 8)
plt.xticks(rotation = 45)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/prezzi_sneaker_effettivi.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
df_scarpe_new['categoria'].unique()
# Out:
# array(['Sneakers alte', None, 'Scarpe skate', 'Sneakers basse',
#        'Scarpe senza lacci', 'Stivali da neve ', 'Stivaletti con plateau',
#        'Stivaletti stringati', 'Stringate sportive',
#        'Stivaletti con tacco', 'Tronchetti', 'Stivali con i lacci'],
#       dtype=object)

# %%
# per genere

palette = ["#003366","#E60012"]   
plt.figure(figsize=(4,8))
sns.countplot(data = df_scarpe_new, x="gender", hue = 'marca', palette = palette)
plt.title("Uomo - Donna - Unisex",fontsize = 20)
plt.xlabel("Gender", fontsize = 15)
plt.ylabel("Conteggio prodotti", fontsize = 15)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Gender.png', dpi=300, bbox_inches='tight')
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
scarpe_invernali = df_scarpe_new.loc[ (df_scarpe_new["modello"].str.contains("WATER", regex = False)) | (df_scarpe_new["modello"].str.contains("WEATHERIZED", regex = False)) | (df_scarpe_new["modello"].str.contains("CLIMATE", regex = False))]
display(scarpe_invernali)

print("Le scarpe invernali sono: \n")
raggrupp_invernali = scarpe_invernali.groupby("marca")["modello"].count().reset_index()
df_ragg_inv = pd.DataFrame(raggrupp_invernali)
display(df_ragg_inv)
# Out:
#          marca                                            modello  \
# 60        VANS                       MTE SK8-HI WATERPROOF UNISEX
# 143   CONVERSE  CHUCK TAYLOR ALL STAR BERKSHIRE BOOT WATER-REP...
# 145       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 148   CONVERSE      CHUCK TAYLOR ALL STAR EQUIP WATERPROOF UNISEX
# 153       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 154   CONVERSE  CHUCK TAYLOR ALL STAR CITY TREK WATERPROOF BOO...
# 157       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 176       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 181       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 192   CONVERSE      CHUCK TAYLOR ALL STAR TECTUFF WATERPROOF CAMO
# 197   CONVERSE  CHUCK TAYLOR ALL STAR CITY TREK WATERPROOF BOO...
# 214       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 219   CONVERSE      CHUCK TAYLOR ALL STAR EQUIP WATERPROOF UNISEX
# 229       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 238       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 239   CONVERSE  CHUCK TAYLOR ALL STAR CITY TREK WATERPROOF UNISEX
# 245   CONVERSE  CHUCK TAYLOR ALL STAR BERKSHIRE WATER REPELLEN...
# 247       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 645       VANS                    MTE OLD SKOOL WATERPROOF UNISEX
# 703       VANS                    MTE OLD SKOOL WATERPROOF UNISEX
# 714       VANS                    MTE OLD SKOOL WATERPROOF UNISEX
# 811       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 812       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 813       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 814       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 815       VANS         MTE STANDARD MID CHELSEA WATERPROOF UNISEX
# 816       VANS                       MTE SK8-HI WATERPROOF UNISEX
# 1038  CONVERSE                  CHUCK TAYLOR ALL STAR WEATHERIZED
# 1060  CONVERSE      CHUCK TAYLOR ALL STAR TECTUFF WATERPROOF CAMO
# 1127  CONVERSE                           CHUCK 70 COUNTER CLIMATE
# 1148  CONVERSE                 RUN STAR HIKE PLATFORM WEATHERIZED
# 1182  CONVERSE                  CHUCK TAYLOR ALL STAR WEATHERIZED
# 1237      VANS                       MTE SK8-HI WATERPROOF UNISEX
# 1936  CONVERSE  CHUCK TAYLOR ALL STAR LUGGED 2.0 WATERPROOF PL...
# 1941      VANS                       MTE SK8-HI WATERPROOF UNISEX
#
#                    categoria                          colore  gender  \
# 60             Sneakers alte                      olive drab  unisex
# 143            Sneakers alte     utility/light filed surplus  unisex
# 145            Sneakers alte                           brown  unisex
# 148            Sneakers alte             black/vintage white  unisex
# 153            Sneakers alte                bitter chocolate  unisex
# 154            Sneakers alte                           black  unisex
# 157            Sneakers alte                  grape leaf/gum  unisex
# 176            Sneakers alte                           black  unisex
# 181            Sneakers alte                    white purple  unisex
# 192            Sneakers alte    bear nap toadstool tan white    uomo
# 197            Sneakers alte              black/white/silver  unisex
# 214            Sneakers alte                            gray  unisex
# 219            Sneakers alte     toadstool tan/vintage white  unisex
# 229            Sneakers alte                       stargazer  unisex
# 238            Sneakers alte       glazed ginger/marshmallow  unisex
# 239            Sneakers alte    bear nap/toadstool tan/black  unisex
# 245            Sneakers alte    bear nap/toadstool tan/white  unisex
# 247            Sneakers alte                           brown  unisex
# 645           Sneakers basse                   glazed ginger  unisex
# 703           Sneakers basse                     black/white  unisex
# 714           Sneakers basse              black/pewter/white  unisex
# 811         Stivali da neve                  chocolate/black  unisex
# 812         Stivali da neve                             teak  unisex
# 813         Stivali da neve                            black  unisex
# 814         Stivali da neve                    glazed ginger  unisex
# 815   Stivaletti con plateau                           brown  unisex
# 816         Stivali da neve                     scarab/black  unisex
# 1038           Sneakers alte  bite the dust/blush hush/egret   donna
# 1060           Sneakers alte    bear nap toadstool tan white   donna
# 1127           Sneakers alte           utility/papyrus/egret   donna
# 1148           Sneakers alte             truffle/black/egret   donna
# 1182           Sneakers alte      shadow woods/utility/egret   donna
# 1237           Sneakers alte                       stargazer  unisex
# 1936        Stivali da neve      fresh brew/fresh brew/black   donna
# 1941        Stivali da neve                     scarab/black  unisex
#
#       prezzo_effettivo  prezzo_ordinario
# 60               79.99            144.99
# 143              51.99             94.99
# 145              79.99            144.99
# 148              64.99            129.99
# 153              79.99            144.99
# 154              65.99            119.99
# 157              79.99            144.99
# 176              79.99            144.99
# 181              79.99            144.99
# 192              80.00             80.00
# 197              65.99            119.99
# 214              79.99            144.99
# 219              70.99            129.99
# 229              71.99            144.99
# 238              79.99            144.99
# 239              65.99            119.99
# 245              51.99             94.99
# 247             122.99            144.99
# 645              73.99            134.99
# 703             114.99            134.99
# 714              73.99            134.99
# 811              79.99            159.99
# 812              87.99            159.99
# 813              79.99            159.99
# 814              87.99            159.99
# 815              84.99            169.99
# 816              87.99            159.99
# 1038             46.99             84.99
# 1060             80.00             80.00
# 1127             79.95             99.95
# 1148             70.99            129.99
# 1182             46.99             84.99
# 1237             79.99            144.99
# 1936             69.99            139.99
# 1941            103.99            159.99
# Le scarpe invernali sono:
#       marca  modello
# 0  CONVERSE       14
# 1      VANS       21

# %%
# per invernali

palette = ["#E60012", "#003366"]   
plt.figure(figsize=(10,8))
sns.barplot(data = df_ragg_inv, y="modello", hue = "marca", palette = palette)
plt.title("Scarpe invernali",fontsize = 20)
plt.xlabel("Modelli", fontsize = 15)
plt.ylabel("Conteggio prodotti", fontsize = 15)
plt.xticks(rotation = 45)
Grafico_altre_categorie = input(f'inserisci il percorso per il salvataggio:')
os.makedirs(Grafico_altre_categorie, exist_ok=True)
plt.savefig(Grafico_altre_categorie + '/Scarpe_invernali.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# inserisci il percorso per il salvataggio: /Users/aidasquadrito/Desktop/Progr.zione/EPICODE/Build_week_3/Grafici

# %%
#Quanti colori abbiamo per modello?



# COLORI!

for iterrows


raggrupp_invernali = scarpe_invernali.groupby(["marca", "modello"])["colore"].count().reset_index()
